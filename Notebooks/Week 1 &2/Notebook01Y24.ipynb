# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# ansi2html                 1.8.0
# anyio                     3.5.0
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# astroid                   2.14.2
# asttokens                 2.0.5
# async-lru                 2.0.4
# attrs                     23.1.0
# autopep8                  1.6.0
# Babel                     2.11.0
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    4.1.0
# Brotli                    1.0.9
# certifi                   2023.11.17
# cffi                      1.16.0
# charset-normalizer        2.0.4
# click                     8.1.7
# colorama                  0.4.6
# comm                      0.1.2
# cryptography              41.0.7
# dash                      2.14.2
# debugpy                   1.6.7
# decorator                 5.1.1
# defusedxml                0.7.1
# dill                      0.3.7
# ...

# %%
#Printing a Love Message
love=input("Enter Name of your Love: ")  #Geting Name of Your Love
sender=input("Enter Your Name:\t") #Name of the Sender
print("\n\n I Love you Baby Girl @ {}. \n\n\t\t From Your Love: {}".format(love,sender))
# Out:
# Enter Name of your Love:  Lydia Muteru
# Enter Your Name:	 Jackrony
#  I Love you Baby Girl @ Lydia Muteru.
#
# 		 From Your Love: Jackrony
