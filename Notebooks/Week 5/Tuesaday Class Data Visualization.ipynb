# %%
# importing libs
import numpy as np 
import pandas as pd 


# Loading Data 
url ='https://raw.githubusercontent.com/Pratik-Bhujade/Diamond-Dataset/master/DiamondData.csv'
Diamond_df = pd.read_csv(url, encoding='utf-8')


Diamond_df.head()
# Out:
#    carat        cut color clarity  depth  table    price     x     y     z
# 0   1.50       Fair     G     SI1   64.5   57.0  10352.0  7.15  7.09  4.59
# 1   0.70      Ideal     E     VS2   61.4   57.0   2274.0  5.72  5.78  3.53
# 2   1.22    Premium     G     VS1   61.3   58.0   8779.0  6.91  6.89  4.23
# 3   0.51    Premium     E     VS2   62.5   60.0   1590.0  5.08  5.10  3.18
# 4   2.02  Very Good     J     SI2   59.2   60.0  11757.0  8.27  8.39  4.91

# %%
Diamond_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    50000 non-null  float64
#  1   cut      50000 non-null  object
#  2   color    50000 non-null  object
#  3   clarity  50000 non-null  object
#  4   depth    49529 non-null  float64
#  5   table    49610 non-null  float64
#  6   price    49747 non-null  float64
#  7   x        49779 non-null  float64
#  8   y        49667 non-null  float64
#  9   z        49572 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Basic Interact

# %%
def func(x):
    return x

# %%
from ipywidgets import interact
from ipywidgets import fixed
interact(func, x=10) ;
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…

# %%
interact(func, x="Hello Jackrony")
# Out:
# interactive(children=(Text(value='Hello Jackrony', description='x'), Output()), _dom_classes=('widget-interact…
# <function __main__.func(x)>

# %%
@interact(x=True, y=1)
def g(x,y):
    return (x,y)
# Out:
# interactive(children=(Checkbox(value=True, description='x'), IntSlider(value=1, description='y', max=3, min=-1…

# %% [markdown]
# ### Fixing Arguments Using Fixed

# %%
def f(p, q):
    return (p,q)
interact(f,p=5, q= fixed(20))
# Out:
# interactive(children=(IntSlider(value=5, description='p', max=15, min=-5), Output()), _dom_classes=('widget-in…
# <function __main__.f(p, q)>

# %%
def r(x):
    return x

interact(r, x= ['Orange','apple','Mango'])
# Out:
# interactive(children=(Dropdown(description='x', options=('Orange', 'apple', 'Mango'), value='Orange'), Output(…
# <function __main__.r(x)>

# %%
interact(func,)

# %%
def f(n,b):
    plt.figure(2)
    x=
    out

# %%
data =

# %%
# %pip install SweetViz
# Out:
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.1 MB 660.6 kB/s eta 0:00:23
#    ---------------------------------------- 0.0/15.1 MB 653.6 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.1 MB 1.1 MB/s eta 0:00:14
#     --------------------------------------- 0.2/15.1 MB 1.3 MB/s eta 0:00:12
#     --------------------------------------- 0.3/15.1 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.3/15.1 MB 1.6 MB/s eta 0:00:10
#    - -------------------------------------- 0.4/15.1 MB 1.7 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/15.1 MB 1.8 MB/s eta 0:00:09
#    - -------------------------------------- 0.7/15.1 MB 2.1 MB/s eta 0:00:08
#    -- ------------------------------------- 0.9/15.1 MB 2.3 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/15.1 MB 2.5 MB/s eta 0:00:06
# ...

# %%
import sweetviz
